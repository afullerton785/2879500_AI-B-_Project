# %% [markdown]
# # AI Generation

# %% [markdown]
# This notebook documents how Generative AI was used in this project to reinterpret the illustrations from the original pamphlet. This notebook will also discuss how these AI systems generate these outputs.

# %% [markdown]
# To create my modernised images from the illustrations in the book, I consulted Google Gemini. I chose Gemini over other alternatives after some testing of other programmes such as ChatGPT, ArtBreeder, and MetaAI. I used Gemini over these options beacuse it was the only programme that could accurately maintain the comic feel of the original images, whilst bringing them forward into the modern day.

# %% [markdown]
# ### How Generative AI Works

# %% [markdown]
# Google Gemini and a plethora of other image generating AI models operate in the same way. These models are trained on massive datasets of images and learn the statistical patterns and distributions within that data. Rather than copying existing images, the model learns relationships between visual features such as shapes, textures, and colours, and uses them to produce an output.
#
# During the training of these models, algorithms such as transformers, diffusion models, and variational autoencoders are used to teach a neural network to capture these patterns as a compact, structured representation in latent space (Sadat et al., 2024). Once training is complete, the model can take new data (the prompts we give it) and generate a new piece of data using the features from its training.
#
# The basic workflow involves:
#
# Training Data -> Algorithm -> Model -> New Input Data -> Generated Output (Cetinic and She, 2022)
#
# In this scenario for example the model takes the original illustration, then to modernise it uses images and text it has been trained on to create an output that should resemble the prompt; in this case the modernised versions of the illustrations from the pamphlet.
#
# Although the AI model generates the images, the process of this generation is very much a collaboration between the human and the AI model. This is because without the input of the human the AI has nothing to make, and the human must be able to select the correct prompts and refine them to create a result that is exactly what was needed (Dang et al., 2022). For example in this project, the human selects the illustrations to be modernised, designs the prompts that will be used to generate images and refines them where necessary, then finally uses these images to influence their own recreation of the illustration.
#
# <sub> Cetinic, E. and She, J., 2022. Understanding and creating art with AI: Review and outlook. ACM transactions on multimedia computing, communications, and applications (TOMM), 18(2), pp.1-22.
#
# <sub> Dang, H., Mecke, L., Lehmann, F., Goller, S. and Buschek, D., 2022. How to prompt? Opportunities and challenges of zero-and few-shot learning for human-AI interaction in creative applications of generative models. arXiv preprint arXiv:2209.01390.
#
# <sub> Sadat, S., Buhmann, J., Bradley, D., Hilliges, O. and Weber, R.M., 2024. Litevae: Lightweight and efficient variational autoencoders for latent diffusion models. Advances in Neural Information Processing Systems, 37, pp.3907-3936.

# %% [markdown]
# ### The Prompts

# %% [markdown]
# This section will display the prompts used for the generation of the modernised images, and will explore how effectively they worked.

# %%
from IPython.display import Image
Image ("Prompt1.jpg")

# %% [markdown]
# This first prompt acts as a set up for the rest of the session to ensure the model understands what it is being asked for. It describes what kind of project will be created and what kind of images will be needed for it.

# %%
from IPython.display import Image
Image ("Prompt2.jpg")

# %% [markdown]
# This prompt highlights the first piece of refinement already, reflecting how invaluable the human-AI working relationship is. The model originally generated a random image without any reference photos, so the second prompt had to narrow the scope to ensure only the illustrations were modernised without any halucinations.

# %%
from IPython.display import Image
Image ("Prompt3.jpg")

# %% [markdown]
# This was the result from the second prompt, which modernised the images quite well, however it lost the hand-drawn feel of the originals, which was something I intended to keep.

# %%
from IPython.display import Image
Image ("Prompt4.jpg")

# %% [markdown]
# This was another attempt at refinement. Gemini took the prompt of splitting the images up to mean three images set apart from each other, all together in the same image, whereas I was looking to get three completely seperate images, further highlighting how invaluable the human side of this transaction is.

# %%
from IPython.display import Image
Image ("Prompt5.jpg")

# %% [markdown]
# This was the stage where the final results were achieved. I elected to take a step back and ask Gemini to modernise each image one at a time in order to get them as three seperate images, and to keep the sketch-like feel of the originals. I then repeated this step for the other two images and achieved my finished products.

# %% [markdown]
# ### The Results

# %%
from IPython.display import Image
Image ("Gemini_Travel.jpg")

# %%
from IPython.display import Image
Image ("Gemini_Drinking.jpg")

# %%
from IPython.display import Image
Image ("Gemini_Header.jpg")

# %% [markdown]
# (All three images credited to Google Gemini, created  March 10 2026)

# %% [markdown]
# These were my finalised results from Gemini. They work really well in bringing the ideas from the original illustrations and transporting them into the modern day.
#
# They do however highlight some issues with AI image generation that are known to be prominant in the field, such as the inability to properly generate anatomy (Käs, Schönherr and Leibe, 2026). The most noticeable example of this comes from the page involving a drink at half time, in which both men have an arm raised. In the original image the man drinking from the bottle is holding it up with his own hand with his arm supported by the other man, however Gemini struggled to distinguish this and generated an image of one man pouring a drink into anothers mouth. I elected to include this in the final project rather than fixing it as I believe it to be a perfect example of where AI image generation still struggles and where a human touch could be deemed necessary to help with the process.
#
# <sub> Käs, S., Schönherr, E. and Leibe, B., 2026. We Still See Broken Limbs: Towards Anatomical Realism in GenAI via Human Preference Learning. In Proceedings of the IEEE/CVF Winter Conference on Applications of Computer Vision (pp. 1038-1047).

# %% [markdown]
# Overall, the use of Gemini to modernise the original illustrations worked as intented for this project. The process has clearly shown how human-AI creativity can thrive as a working relationship because human input is essential to getting the best out of the AI model, as is evidenced through the prompts section of this project.
