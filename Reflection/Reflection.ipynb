# %% [markdown]
# # Reflection

# %% [markdown]
# This notebook critically reflects on the outcomes of this project and analyses how generative AI and humans have interacted with the item of cultural heritage, 'Free Kicks at Football'. The analysis will focus on how AI generation and human recreation differed in their interpretations of the original illustration, and wherein lies certain positives and negatives.

# %% [markdown]
# ### Project Aim
#
# This project aimed to engage a general audience with 'Free Kicks at Football' by reinterpreting the illustrations through both generative AI and human recreation, highlighting how meaning shifts across time, technology, and personnel; doing so through exploration of how AI systems operate and how humans interact with them.

# %% [markdown]
# ### AI Generation Analysis

# %%
from IPython.display import display, HTML

img1 = "Travel_Original.jpg"
img2 = "Gemini_Travel.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This generation could be argued to be the one that changed the most. It completely transformed the original illustration from the horse drawn carriage and the bus in the background to a depiction of a bustling city centre featuring cars, bikes, taxis, buses and a train. This does a fantastic job at reflecting the options for travel to football games in the modern day, however does have some flaws. As is considered common with AI generation, much of the illustration is not entirely accurate, with the taxi on the pavement and the train on the road in front of a car. Granted, this is not much of an issue for this project as this was more about bringing forth the idea of travel rather than the accuracy of it, however it is worth noting for any future projects.

# %%
from IPython.display import display, HTML

img1 = "Drinking_Original.jpg"
img2 = "Gemini_Drinking.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This generation again does a fantastic job at bringing the original illustration into the modern world. It changes multiple aspects of the original such as clothing, setting, and even the area surrounding the book, however the most notable change is the introduction of people of colour. This is a perfect reflection of the behaviour of AI generative models, as it suggests that Gemini is reflecting the patterns of images it has been trained on, as it has noticed the increased diversity in the present, compared to that of the time the pamphlet was created. One could also suggest that these generations may reflect the rise in AI bias accusations in recent years. This case can be presented as Google perhaps implementing some form of diversity protocols in order to combat the white-bias that is prevalent in many AI models (Berendt and Kiyak, 2026).
#
# <sub> Berendt, B. and Kiyak, S., 2026. De-biased, Diverse, Divisive. Understanding the Google Gemini Internet Storm in the Broader Context of Diversity, Generative AI, and Interdisciplinary Uses of Data. In Charting the Future of Historical Humanities (pp. 185-215). Brepols Online.

# %%
from IPython.display import display, HTML

img1 = "Header_Original.jpg"
img2 = "Gemini_Header.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This final modernisation is arguably the one that stayed most faithful to the source material, largely keeping positions and background the same. The most interesting piece of modernisation however is the setting of the stadium, in which "Glasgow Football" is written on many areas. This can be considered especially interesting when critically evaluating the behaviour of AI, as where it could have gotten this information is very important. This being the last of the three Gemini generated is incredibly important to this analysis. It suggests that after seeing the first illustration with the 'University of Glasgow' stamp on it, Gemini proceeded to carry this information and implement it on the future generations; shown here through the writing of "Glasgow Football" across the stadium. This could reflect a common behaviour of many AI models, potentially using previous prompts and generations as an influence for how they behave in future generations.

# %% [markdown]
# ### Human Recreation Analysis

# %%
from IPython.display import display, HTML

img1 = "Travel_Original.jpg"
img2 = "Travel_Recreation_Car.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This human recreation only focuses on one area of travel, which is not entirely representative of the multiple options available in the present. I chose it however as I believe it provides the best parallel to the original illustration, as one could argue that the cars now used to get to games are the natural evolution of what once was the horse drawn carriage.

# %%
from IPython.display import display, HTML

img1 = "Drinking_Original.jpg"
img2 = "Drinking_Recreation.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This recreation is almost like-for-like to the original illustration. The setting of the recreation being outside Firhill Stadium, the home of Partick Thistle FC, adds an element to the comparison as the original illustraion features only the two men with no background. This highlights where human creativity was implemented in recreation as the recreators chose to go out their way and take the photo on location, rather than just in a neutral setting.

# %%
from IPython.display import display, HTML

img1 = "Header_Original.jpg"
img2 = "Header_Recreation.jpg"

html_str = f"""
<div style="display: flex; justify-content: center;">
    <img src="{img1}" style="width: 45%; margin: 5px;">
    <img src="{img2}" style="width: 45%; margin: 5px;">
</div>
"""

display(HTML(html_str))

# %% [markdown]
# This recreation best highlights the ways in which human interterpretation can differ from that of the source material. In this recreation the essence of the original image is still there, as the ball is between two players on a football pitch, however the original clearly shows a player winning a header over their opponent, whereas the recreation shows the ball falling in between the players, neither challenging for the player. This is a great example of how humans can interpret cultural heritage artificats in ways the deviate from the source material, whilst still mainting the essence.

# %% [markdown]
# ### Human-AI Collaboration

# %% [markdown]
# This project has highlighted how AI models and humans can interpret items of cultural heritage differently. It has found that both sides come with flaws in their interpretations. For AI models this arises through hallucinations, struggling with interpreting limbs, and from protocols altering how the model behaves. For humans these flaws are the inability to show more than one mode of transport at once, and the difficulty of perfectly posing in the same way as the original illustration.
#
# However, both sides have benefits in their own ways, with AI able to produce arguably more detailed images, whereas human recreations copuld be argued to contain a ceratin emotive quality, more of the 'soul' from the original illustrations.
#
# These flaws and benefits come together to form the central argument of this project: humans and AI models can be more effective working creatively together, rather than as separate entities. Instead of pitting both against each other, it would be beneficial to pair them together, in the likelihood of achieving an outcome greater than what either side could achieve alone.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# This project has evaluated how generative AI and humans can engage with an item of cultural heritage, in this case the pamphlet 'Free Kicks at Football' from the University of Glasgow Special Collections. It has shown how both can interpret source material in different ways, prompting creativity to be explored in different lights. It has found that AI tends to be better at producing more detailed interpretations, whereas humans create more 'soulful' interpretations, bringing forth the central idea that AI models and humans are a better creative force together, than they are apart.
#
# Overall, this project has come to the conclusion that the interaction between the original illustrations, the AI-generated images, and the human recreations perfectly summarise how meaning of a piece of cultural heritage shifts across different times, technologies, and persons.
